# %%
for i in range(1,11):
  print('datascience and dataanalytics',i)
# Out:
# datascience and dataanalytics 1
# datascience and dataanalytics 2
# datascience and dataanalytics 3
# datascience and dataanalytics 4
# datascience and dataanalytics 5
# datascience and dataanalytics 6
# datascience and dataanalytics 7
# datascience and dataanalytics 8
# datascience and dataanalytics 9
# datascience and dataanalytics 10

# %%
for i in range(1,5):
  print('goodmorning',i)
  for j in range(1,3):
    print('good afternoon',j)
# Out:
# goodmorning 1
# good afternoon 1
# good afternoon 2
# goodmorning 2
# good afternoon 1
# good afternoon 2
# goodmorning 3
# good afternoon 1
# good afternoon 2
# goodmorning 4
# good afternoon 1
# good afternoon 2

# %%
n=5
r=2
for i in range(n):
  print(r*i,end=' ')
# Out:
# 0 2 4 6 8

# %%
print('goodmorning')
for i in range(1,4):
  print('riya',end=' ')
print()
print('goodafternoon')
# Out:
# goodmorning
# riya riya riya
# goodafternoon

# %%
n=8
sum=0
for i in range(1,n):
  if n%i==0:
    sum=sum+i
if(sum==n) :
  print(f'{sum} it is a perfect number')
else:
  print(f'{sum} it is not a perfect number')
# Out:
# 7 it is not a perfect number

# %%
word=''
while word!='stop':
  word=input('enter a word:')
print("program stopped")
# Out:
# enter a word:supriya
# enter a word:stop
# program stopped

# %%
for i in range(1,4):
  for j in range(1,4):
    print(j,end=' ')
  print()
# Out:
# 1 2 3
# 1 2 3
# 1 2 3

# %%
num=0
while num<=50:
  num=int(input('enter a number:'))
print('loop stopped because it is greater than 50')
# Out:
# enter a number:6
# enter a number:7
# enter a number:51
# loop stopped because it is greater than 50

# %%
year=1900
if year%4==0:
  if year%100==0:
    if year%400==0:
      print('leap year')
    else:
      print('not leap year')
  else:
    print('leap year')
else:
  print('not a leap year')
# Out:
# not leap year
