# %% [markdown]
# **Classwork**

# %%
n=2
f=lambda x,y:x*y
for i in range(1,11):
  print(f'{n} * {i} = {f(n,i)}')
# Out:
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20

# %%
sol=map(lambda x:x%2==0,[10,11,12,13,14])
print(list(sol))
# Out:
# [True, False, True, False, True]

# %%
sol=filter(lambda x:x%2==0,[10,11,12,13,14])
print(list(sol))
# Out:
# [10, 12, 14]

# %%
import functools
f=[1,4,9,7]
sol=functools.reduce(lambda x,y:x+y ,f)
print(sol)
# Out:
# 21

# %%
a=map(lambda x:x+20, filter(lambda x:x%2==0,[10,11,12,13]))
print(list(a))
# Out:
# [30, 32]

# %%
a=filter(lambda x:x%2==0 ,map(lambda x:x+20,[101,102]))
print(list(a))
# Out:
# [122]

# %%
import functools
a=functools.reduce(lambda x,y:x+y,map(lambda x:x+20,filter(lambda x:x%2==0,[1,2,3])))
print(a)
# Out:
# 22

# %% [markdown]
# **Examples**

# %%
num=[1,2,3,4]
is_even=lambda x:x%2==0
is_odd=lambda x:x%2!=0
e=[]
o=[]
for i in num:
  if is_even(i):
    e.append(i)
  else:
    o.append(i)
print(e)
print(o)
# Out:
# [2, 4]
# [1, 3]

# %%
a= lambda x:x+30
print('sum=',a(10))
# Out:
# sum= 40

# %%
a=lambda x,y:x-y
print('sub=',a(20,10))
# Out:
# sub= 10

# %% [markdown]
# **Assignment**

# %%
a=lambda x:x**2
for i in range(1,6):
  print(f'square of number:',a(i))
# Out:
# square of number: 1
# square of number: 4
# square of number: 9
# square of number: 16
# square of number: 25

# %%
max_num=lambda x,y: x if x>y else y
print(max_num(10,20))
# Out:
# 20

# %%
a=map(lambda x:x+x ,[1,2,3,4,5])
print(list(a))
# Out:
# [2, 4, 6, 8, 10]

# %%
a=filter(lambda x:x%2==0,[1,2,3,4,5])
print(list(a))
# Out:
# [2, 4]
