# %% [markdown]
# **Classwork**

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
len(dir(str))
# Out:
# 81

# %%
a='india'
a
# Out:
# 'india'

# %%
print(a[0])
# Out:
# i

# %%
print(a[-1])
# Out:
# a

# %%
print(a[1]+a[3])
# Out:
# aa

# %%
a='data science'
print(a[1:4])
# Out:
# ata

# %%
a='data science'
print(a[-11:-3])
# Out:
# ata scie

# %%
a='data science'
a[1:3:1]
# Out:
# 'at'

# %%
a='data science'
print(a[4:11:3])
# Out:
#  ic

# %%
a='data science'
print(a[::-1])
# Out:
# ecneics atad

# %%
print(a[::1])
# Out:
# data science

# %%
print(a[::-2])
# Out:
# enisaa

# %%
print(a[9:3:-1])
# Out:
# neics

# %%
a='data science'
a[4]='j'
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4060823987.py in <cell line: 0>()
#       1 a='data science'
# ----> 2 a[4]='j'
#       3 print(a)
#
# TypeError: 'str' object does not support item assignment

# %%
a='data science'
del a[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1853088688.py in <cell line: 0>()
#       1 a='data science'
# ----> 2 del a[1]
#
# TypeError: 'str' object doesn't support item deletion

# %%
a='data science'
a=a.capitalize()
print(a)
# Out:
# Data science

# %%
print(a.title())
# Out:
# Data Science

# %%
print(a.upper())
# Out:
# DATA SCIENCE

# %%
a='dATA scIEnce'
c=a.lower()
print(c)
# Out:
# data science

# %%
print(c.isupper())
# Out:
# False

# %%
print(c.islower())
# Out:
# True

# %%
a='supriya'
print(a.startswith('p'))
# Out:
# False

# %%
print(a.endswith('a'))
# Out:
# True

# %%
print(a.isalpha())
# Out:
# True

# %%
a='124 5'
print(a.isnumeric())
# Out:
# False

# %%
a='abccc 23'
print(a.isalnum())
# Out:
# False

# %%
a='supriya'
a=a.replace('a','aa')
print(a)
# Out:
# supriyaa

# %%
print(a.replace('a','p',1))
# Out:
# supriypa

# %%
print(a.index('a'))
# Out:
# 6

# %%
a='data science uk'
end=a[a.index('e',9)
start=a[:a.index('e',9)]
f=end.replace('e','p')
print(start+f)
# Out:
# 11
# e uk
# data sciencp uk

# %%
a='supriya ya ya ya'
ends=a[a.index('a',10):]
print(ends)
starts=a[:a.index('a',10)]
f=ends.replace('a','p')
print(starts+f)
# Out:
# a ya
# supriya ya yp yp

# %%
a='vamssi'
print(a.count('s'))
# Out:
# 2

# %%
a='vamssi supriya'
print('supriya' in a)
# Out:
# True

# %%
ord('z')
# Out:
# 122

# %%
chr(98)
# Out:
# 'b'

# %% [markdown]
# **Assignment**

# %%
a=input('enter a string:')
print(len(a))
# Out:
# enter a string:supriya
# 7

# %%
a='supriya'
print(a[0])
print(a[-1])
# Out:
# s
# a

# %%
a='supriya'
print(a[2])
print(a[-2])
# Out:
# p
# y

# %%
a='supriya'
b=a[(len(a)-1)//2]
print(b)
# Out:
# r

# %%
a='supriya'
print(a[::-1])
# Out:
# ayirpus

# %%
a='supriya'
print(a[0:5])
print(a[-5:])
# Out:
# supri
# priya

# %%
a='supriya'
print(a[1::2])
# Out:
# ury

# %%
a='  supriy a'
b=list(a)
c=[]
for i in b:
  if i!=' ':
    c.append(i)
print(''.join(c))
# Out:
# supriya

# %%
a='supriya'
print(a.upper())
print(a.lower())
# Out:
# SUPRIYA
# supriya

# %%
a='s u p r i y a'
b=a.replace(' ','-')
print(b)
# Out:
# s-u-p-r-i-y-a

# %%
a='supriya'
print( a[0]=='A' or a[-1]=='Z')
# Out:
# False

# %%
a='supriya'
print(a.count('a'))
# Out:
# 1

# %%
a='supriya'
b='riya'
print(a.index('riya'))
# Out:
# 3

# %%
a='india is a beautiful country'
b=a.split()
print(b[0])
# Out:
# india

# %%
a='alpha'
if a.isnumeric():
  print('True')
else:
  print('false')
# Out:
# false

# %%
a=['india','is','a','beautiful','country']
print(','.join(a))
# Out:
# india,is,a,beautiful,country

# %%
a='supriya'
b='sUPRIYA'
c=a.lower()
d=a.lower()
if c==d:
  print('True')
# Out:
# True

# %%
a='supriya'
print(a[-1]+a[1:len(a)-1]+a[0])
# Out:
# aupriys
