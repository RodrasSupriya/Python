# %% [markdown]
# **ClassWork**

# %%
a=10
print(float(a))
print(str(a))
# Out:
# 10.0
# 10

# %%
a=50.00
print(int(a))
print(str(a))
# Out:
# 50
# 50.0

# %%
a='supriya'
print(int(a))
print(float(a))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2670786740.py in <cell line: 0>()
#       1 a='supriya'
# ----> 2 print(int(a))
#       3 print(float(a))
#       4 a='123'
#       5 print(int(a))
#
# ValueError: invalid literal for int() with base 10: 'supriya'

# %%
a='123'
print(int(a))
print(float(a))
# Out:
# 123
# 123.0

# %%
a=20
name='supriya'
print('My age is:',a)
print('my name is:'+str(name))
print('my age %d and name is %s'%(a,name))
print(f'My name is {name} and age is {a}')
# Out:
# My age is: 20
# my name is:supriya
# my age 20 and name is supriya
# My name is supriya and age is 20
