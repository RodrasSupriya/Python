# %%
a={'Name':'Supriya','Age':27,'Class':'B.tech'}
print(a)
# Out:
# {'Name': 'Supriya', 'Age': 27, 'Class': 'B.tech'}

# %%
print(a.get('Name'))
# Out:
# Supriya

# %%
a.update({'percentage':8.67})
print(a)
# Out:
# {'Name': 'Supriya', 'Age': 27, 'Class': 'B.tech', 'percentage': 8.67}

# %%
a.popitem()
print(a)
# Out:
# {'Name': 'Supriya', 'Age': 27, 'Class': 'B.tech'}

# %%
print(a.pop('Class'))
# Out:
# B.tech

# %%
print(a.keys())
# Out:
# dict_keys(['Name', 'Age'])

# %%
print(a.values())
# Out:
# dict_values(['Supriya', 27])

# %%
print(a.items())
# Out:
# dict_items([('Name', 'Supriya'), ('Age', 27)])

# %%
a.clear()
print(a)
# Out:
# {}

# %%
a={'name':'supriya','class':'b.tech'}
b=a
print(a)
print(b)
print(id(a))
print(id(b))
a['age']=27
print(a)
print(b)
# Out:
# {'name': 'supriya', 'class': 'b.tech'}
# {'name': 'supriya', 'class': 'b.tech'}
# 133447721048576
# 133447721048576
# {'name': 'supriya', 'class': 'b.tech', 'age': 27}
# {'name': 'supriya', 'class': 'b.tech', 'age': 27}

# %%
a={'name':'supriya','class':'b.tech'}
b=a.copy()
print(a)
print(b)
print(id(a))
print(id(b))
a['age']=27
print(a)
print(b)
# Out:
# {'name': 'supriya', 'class': 'b.tech'}
# {'name': 'supriya', 'class': 'b.tech'}
# 133447718817152
# 133447720049536
# {'name': 'supriya', 'class': 'b.tech', 'age': 27}
# {'name': 'supriya', 'class': 'b.tech'}

# %%
a={'name':['supriya','renuka'],
   'class':['b.tech','mba'],
   }

# %%
print(a['name'][0])
# Out:
# supriya

# %%
print(a['class'][0:2])
# Out:
# ['b.tech', 'mba']

# %%
b=a['class']
print(b.count('b.tech'))
# Out:
# 1

# %%
mydict = {'name': 'ashu', 'age': 45, 'gender': 'female'}
del mydict
print(mydict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-235879642.py in <cell line: 0>()
#       1 mydict = {'name': 'ashu', 'age': 45, 'gender': 'female'}
#       2 del mydict
# ----> 3 print(mydict)
#
# NameError: name 'mydict' is not defined

# %%
dict1={'a':20,'b':10}
dict2=dict(dict1)
print(dict2)
# Out:
# {'a': 20, 'b': 10}

# %% [markdown]
# **Assignments**

# %%
d={'name':'supriya','class':'b.tech','branch':'cse'}
print(d)
# Out:
# {'name': 'supriya', 'class': 'b.tech', 'branch': 'cse'}

# %%
d={'name':'supriya','class':'b.tech','branch':'cse'}
print(d['name'])
# Out:
# supriya

# %%
d={'name':'supriya','class':'b.tech','branch':'cse'}
print(d.get('name'))
# Out:
# supriya

# %%
d={'name':'supriya','class':'b.tech','branch':'cse'}
b=d.update({'clg':'GPCET'})
print(d)
# Out:
# {'name': 'supriya', 'class': 'b.tech', 'branch': 'cse', 'clg': 'GPCET'}

# %%
e={'clg':'GPCET'}
e.pop('clg')
print(e)
# Out:
# {}

# %%
a={'name': 'supriya', 'class': 'b.tech', 'branch': 'cse', 'clg': 'GPCET'}
print('name' in a)
# Out:
# True

# %%
print(a.keys())
# Out:
# dict_keys(['name', 'class', 'branch', 'clg'])

# %%
print(a.values())
# Out:
# dict_values(['supriya', 'b.tech', 'cse', 'GPCET'])

# %%
print(a.items())
# Out:
# dict_items([('name', 'supriya'), ('class', 'b.tech'), ('branch', 'cse'), ('clg', 'GPCET')])

# %%
a={'name': 'supriya', 'class': 'b.tech', 'branch': 'cse', 'clg': 'GPCET'}
for key,val in a.items():
  print(key,val)
# Out:
# name supriya
# class b.tech
# branch cse
# clg GPCET

# %%
a={'name': 'supriya', 'class': 'b.tech', 'branch': 'cse', 'clg': 'GPCET'}
b=a.copy()
a.update({'surname':'supriya'})
print(a)
print(b)
# Out:
# {'name': 'supriya', 'class': 'b.tech', 'branch': 'cse', 'clg': 'GPCET', 'surname': 'supriya'}
# {'name': 'supriya', 'class': 'b.tech', 'branch': 'cse', 'clg': 'GPCET'}

# %%
a={'name': 'supriya', 'class': 'b.tech', 'branch': 'cse', 'clg': 'GPCET'}
a.setdefault('surname','rodras')
print(a)
# Out:
# {'name': 'supriya', 'class': 'b.tech', 'branch': 'cse', 'clg': 'GPCET', 'surname': 'rodras'}

# %%
a={'name': 'supriya', 'class': 'b.tech', 'branch': 'cse', 'clg': 'GPCET'}
a['surname']='rodras'
print(a)
# Out:
# {'name': 'supriya', 'class': 'b.tech', 'branch': 'cse', 'clg': 'GPCET', 'surname': 'rodras'}

# %%
a=dict([("a",1),("b",2)])
print(a)
# Out:
# {'a': 1, 'b': 2}
