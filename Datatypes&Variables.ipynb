# %% [markdown]
# **classwork**

# %%
print(type(12))
print(type(56.77))
print(type('kumar'))
print(type('125'))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %%
a=12
a
# Out:
# 12

# %%
print(a)
# Out:
# 12

# %%
print(id(a))
# Out:
# 11654728

# %%
10a=100
print(10a)
# Out:
#   File "/tmp/ipython-input-3381053880.py", line 1
#     10a=100
#      ^
# SyntaxError: invalid decimal literal

# %%
_10a=100
print(_10a)
# Out:
# 100

# %%
A=100
print(A)
# Out:
# 100

# %%
name city= supriya
print(name city)
# Out:
#   File "/tmp/ipython-input-2700229418.py", line 1
#     name city= supriya
#          ^
# SyntaxError: invalid syntax

# %%
@a=10
print(@a)
# Out:
#   File "/tmp/ipython-input-38962059.py", line 1
#     @a=10
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# **Examples**

# %%
a,b,c=10,20,30
print(a,b,c)
print(a)
# Out:
# 10 20 30
# 10

# %% [markdown]
# **Assignment**

# %%
print(bool(''))
# Out:
# False

# %%
print(5+True)
# Out:
# 6

# %%
print(int(True))
# Out:
# 1

# %%
print(bool(0))
# Out:
# False

# %%
a=' supriya '
b=a.strip()
print(b)
# Out:
# supriya

# %%
n=5
for i in range(1,11):
  print(f'{n} * {i}={n*i}')
# Out:
# 5 * 1=5
# 5 * 2=10
# 5 * 3=15
# 5 * 4=20
# 5 * 5=25
# 5 * 6=30
# 5 * 7=35
# 5 * 8=40
# 5 * 9=45
# 5 * 10=50

# %%
print(bin(2))
print(oct(2))
print(hex(2))
# Out:
# 0b10
# 0o2
# 0x2

# %%
a=20
print(id(a))
b=20
print(id(b))
# Out:
# 11654984
# 11654984
