# %%
a={1,23,34}
print(a)
# Out:
# {1, 34, 23}

# %%
print(a)
# Out:
# {1, 34, 23}

# %%
a.add(2)
print(a)
# Out:
# {1, 34, 2, 23}

# %%
a.update([21,345,346])
print(a)
# Out:
# {1, 34, 2, 21, 23, 345, 346}

# %%
a.pop()
print(a)
# Out:
# {34, 2, 21, 23, 345, 346}

# %%
print(a)
# Out:
# {34, 21, 23, 345, 346}

# %%
a.remove(21)
print(a)
# Out:
# {34, 23, 345, 346}

# %%
a.remove(50)
print(a)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2021087605.py in <cell line: 0>()
# ----> 1 a.remove(50)
#       2 print(a)
#
# KeyError: 50

# %%
a.discard(345)
print(a)
# Out:
# {34, 23, 346}

# %%
a.discard(3)
print(a)
# Out:
# {34, 23, 346}

# %%
a={1,23,3232,323,'supriya'}
b={'supriya',23,232,33}
print(a.union(b))
# Out:
# {3232, 1, 33, 'supriya', 323, 232, 23}

# %%
print(a.intersection(b))
# Out:
# {'supriya', 23}

# %%
a={10,33,89,3}
b=a
print(a)
print(b)
print(id(a))
print(id(b))
a.add(45)
print(a)
print(b)
# Out:
# {89, 10, 3, 33}
# {89, 10, 3, 33}
# 135615251549984
# 135615251549984
# {33, 3, 10, 45, 89}
# {33, 3, 10, 45, 89}

# %%
a={10,33,89,3}
b=a.copy()
print(a)
print(b)
print(id(a))
print(id(b))
a.add(45)
print(a)
print(b)
# Out:
# {89, 10, 3, 33}
# {89, 10, 3, 33}
# 135614689996448
# 135614689991072
# {33, 3, 10, 45, 89}
# {89, 10, 3, 33}

# %%
a={2,4,8,89}
a.clear()
print(a)
# Out:
# set()

# %%
b=set()
b.add(21)
b.add(34)
print(b)
# Out:
# {34, 21}

# %%
a={12,323,2323,2323}
print(a)
# Out:
# {323, 2323, 12}

# %%
print(a[0])
print(a[0:])
print(a[1::-1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1960634063.py in <cell line: 0>()
# ----> 1 print(a[0])
#       2 print(a[0:])
#       3 print(a[1::-1])
#
# TypeError: 'set' object is not subscriptable

# %%
a={1.2,'data',[123,323]}
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-803302434.py in <cell line: 0>()
# ----> 1 a={1.2,'data',[123,323]}
#       2 print(a)
#
# TypeError: unhashable type: 'list'

# %%
a={1.2,'data',(123,323)}
print(a)
# Out:
# {1.2, 'data', (123, 323)}

# %% [markdown]
# **Assignment**

# %%
a={1,23,232,32,2}
print(a)
# Out:
# {32, 1, 2, 23, 232}

# %%
a.add(45)
print(a)
# Out:
# {32, 1, 2, 23, 232, 45}

# %%
a.remove(2)
print(a)
# Out:
# {32, 1, 23, 232, 45}

# %%
l=[1,2,3,4]
b=set(l)
print(b)
# Out:
# {1, 2, 3, 4}

# %%
1 in b
# Out:
# True

# %%
s1={1,2,2}
s2={2,3,34}
b=s1.union(s2)
print(b)
# Out:
# {1, 2, 3, 34}

# %%
s1={1,2,2}
s2={2,3,34}
b=s1.intersection(s2)
print(b)
# Out:
# {2}

# %%
s1={1,2,2}
s2={2,3,34}
b=s1.symmetric_difference(s2)
print(b)
# Out:
# {1, 3, 34}

# %%
a={1,2,3}
a.clear()
print(a)
# Out:
# set()

# %%
a='supriya'
b=set(a)
print(b)
# Out:
# {'a', 'u', 'r', 'p', 's', 'y', 'i'}

# %%
s1={1,2,2}
s2={1,2}
print(s2.superset(s1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3304444789.py in <cell line: 0>()
#       1 s1={1,2,2}
#       2 s2={1,2}
# ----> 3 print(s2.superset(s1))
#
# AttributeError: 'set' object has no attribute 'superset'

# %%
s1={1,2,3}
s2={2,3}
print(s1.disjoint(s2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3015132215.py in <cell line: 0>()
#       1 s1={1,2,3}
#       2 s2={2,3}
# ----> 3 print(s1.disjoint(s2))
#
# AttributeError: 'set' object has no attribute 'disjoint'

# %%
s1={1,2,3,4,5}
s2=len(s1)
print(s2)
# Out:
# 5

# %%
s1.pop()
print(s1)
# Out:
# {2, 3, 4, 5}

# %%
s1={1,2,3}
s2=s1
print(s2)
# Out:
# {1, 2, 3}

# %%
t=(1,2,3)
a=set(t)
print(a)
# Out:
# {1, 2, 3}
