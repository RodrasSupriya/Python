# %% [markdown]
# **Assignment**

# %%
a=34
if (a>=10 and a<=50):
  print('True')
# Out:
# True

# %%
a=10
b=20
a=a+b
b=a-b
a=a-b
print(a,b)
# Out:
# 20 10

# %%
a='supriya'
print('a' in a)
# Out:
# True

# %%
print(7&3)
print(7|3)
# Out:
# 3
# 7

# %%
a=101
if 100<a<200:
  print('True')
# Out:
# True

# %%
print(ord('a'))
print(ord('A'))
print(ord('Z'))
print(ord('z'))
# Out:
# 97
# 65
# 90
# 122
