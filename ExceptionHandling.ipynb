# %%
try:
  a=10
  b=0
  print(a/b)
except Exception as e:
  print(e)
# Out:
# division by zero

# %%
try:
  a=10
  b=0
  print(a/b)
except ValueError as e:
  print(e)
except NameError as e:
  print(e)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-597269114.py in <cell line: 0>()
#       2   a=10
#       3   b=0
# ----> 4   print(a/b)
#       5 except ValueError as e:
#       6   print(e)
#
# ZeroDivisionError: division by zero

# %%
import os
import sys
try:
  a=10
  b=0
  print(a/b)
except Exception as e:
  error_type,error_msg,error_line=sys.exc_info()
  print(f'Error type:{error_type}')
  print(f'Error message:{error_msg}')
  print(f'Error line:{error_line.tb_lineno}')
# Out:
# Error type:<class 'ZeroDivisionError'>
# Error message:division by zero
# Error line:6

# %%
try:
  a=10
  b=0
  print(a/b)
except Exception as e:
  print(e)
finally:
  print('executes with error or without error')
# Out:
# division by zero
# executes with error or without error

# %%
n=2
f=lambda x,y:x*y
for i in range(1,11):
  return f
# Out:
#   File "/tmp/ipython-input-1625959858.py", line 4
#     return f
#     ^
# SyntaxError: 'return' outside function
