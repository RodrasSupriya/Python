# %% [markdown]
# **Assignments**

# %%
a=10
b=20
if a>b:
  print(a)
else:
  print(b)
# Out:
# 20

# %%
a=20
if a>10:
  print(a)
elif a==20:
  print('it is equal')
# Out:
# 20

# %%
a=10
b=20
c=30
if a>b:
  print(a)
elif b>c:
  print(b)
else:
  print(c)
# Out:
# 30
