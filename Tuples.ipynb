# %% [markdown]
# #***classwork***

# %%
a=123,333,'adf',34.5
print(a)
print(type(a))
# Out:
# (123, 333, 'adf', 34.5)
# <class 'tuple'>

# %%
a=(2,34,34,4)
a[4]=45
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4066298465.py in <cell line: 0>()
#       1 a=(2,34,34,4)
# ----> 2 a[4]=45
#       3 print(a)
#
# TypeError: 'tuple' object does not support item assignment

# %%
b=(1,23,3)
del b
print(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1222737619.py in <cell line: 0>()
#       1 b=(1,23,3)
#       2 del b
# ----> 3 print(b)
#
# NameError: name 'b' is not defined

# %%
a=(1,23,33)
b=a.index(23)
print(b)
# Out:
# 1

# %%
a=(1,23,2,32,232,323,23)
print(a.count(23))
# Out:
# 2

# %%
a='supriya','btech',8.73#development level
print(a)
# Out:
# ('supriya', 'btech', 8.73)

# %%
name,education,percentage=a#production level
print(name)
print(education)
print(percentage)
# Out:
# supriya
# btech
# 8.73

# %% [markdown]
# #***Examples***

# %%
a=(1,23,32,323,4)
print(a[0])
print(a[0:])
print(a[::2])
# Out:
# 1
# (1, 23, 32, 323, 4)
# (1, 32, 4)

# %%
a=(12,2,23,'supriya',[2323,45])
print(a)
# Out:
# (12, 2, 23, 'supriya', [2323, 45])

# %%
a=(10,)
print(type(a))
a=(10)
print(type(a))
# Out:
# <class 'tuple'>
# <class 'int'>

# %%
a=(12,323,23)
b=(1,23,3,3)
a=a+b
print(a)
# Out:
# (12, 323, 23, 1, 23, 3, 3)

# %%
a=tuple('supriya')
print(a)
# Out:
# ('s', 'u', 'p', 'r', 'i', 'y', 'a')

# %%
print(''.join(a))
# Out:
# supriya

# %%
a=(123,23,232353,12)
print(max(a))
print(min(a))
print(sum(a))
print(len(a))
print(sorted(a))
print(sorted(a,reverse=True))
print(123 in a)
# Out:
# 232353
# 12
# 232511
# 4
# [12, 23, 123, 232353]
# [232353, 123, 23, 12]
# True

# %%
a=(1,2)*5
print(a)
# Out:
# (1, 2, 1, 2, 1, 2, 1, 2, 1, 2)

# %%
a=(1,23,3,3,23)
print(a.index(23))
print(a.count(3))
# Out:
# 1
# 2

# %% [markdown]
# **Assignments**

# %%
a='python'
b=tuple(a)
print(b)
# Out:
# ('p', 'y', 't', 'h', 'o', 'n')

# %%
a=('p', 'y', 't', 'h', 'o', 'n')
b=a*2
print(b)
# Out:
# ('p', 'y', 't', 'h', 'o', 'n', 'p', 'y', 't', 'h', 'o', 'n')

# %%
a=('p', 'y', 't', 'h', 'o', 'n')
b=''.join(a)
print(b)
# Out:
# python
